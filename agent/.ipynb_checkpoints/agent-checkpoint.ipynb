# %% [markdown]
# ## Importação de Bibliotecas

# %%
from train import Train
import matplotlib.pyplot as plt

train = Train(False)
train.start()
# Out:
# load memory len -> (77)
# Listining to  Address:  0.0.0.0 Port:  2223
# 1/1 [==============================] - 0s 98ms/step
# Episode==>0, Step==>1, Reward==>6.0226223434298, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 47ms/step
# Episode==>0, Step==>2, Reward==>6.213964006813599, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 67ms/step
# Episode==>0, Step==>3, Reward==>6.430897786921101, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 32ms/step
# Episode==>0, Step==>4, Reward==>6.5637899600175995, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 40ms/step
# Episode==>0, Step==>5, Reward==>6.7483125692197, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 74ms/step
# Episode==>0, Step==>6, Reward==>6.9645193454185, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 66ms/step
# Episode==>0, Step==>7, Reward==>7.215410534759799, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 21ms/step
# Episode==>0, Step==>8, Reward==>7.265839180553001, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 62ms/step
# Episode==>0, Step==>9, Reward==>7.4011848054605, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 47ms/step
# Episode==>0, Step==>10, Reward==>7.571851552593101, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 43ms/step
# Episode==>0, Step==>11, Reward==>7.7519344579186, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 45ms/step
# Episode==>0, Step==>12, Reward==>7.9008541572101, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 40ms/step
# Episode==>0, Step==>13, Reward==>-2.2815524700444003, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 54ms/step
# Episode==>0, Step==>14, Reward==>-2.6072209933871004, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 45ms/step
# Episode==>0, Step==>15, Reward==>-2.9083765379082003, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 80ms/step
# Episode==>0, Step==>16, Reward==>-3.2335021431644995, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 35ms/step
# Episode==>0, Step==>17, Reward==>-3.533859590803301, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 71ms/step
# Episode==>0, Step==>18, Reward==>-3.8844583265483, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 75ms/step
# Episode==>0, Step==>19, Reward==>-4.2350020124963, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 48ms/step
# Episode==>0, Step==>20, Reward==>-4.5601751119288, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 40ms/step
# Episode==>0, Step==>21, Reward==>-4.88520885106, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 54ms/step
# Episode==>0, Step==>22, Reward==>-5.237433076099, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 31ms/step
# Episode==>0, Step==>23, Reward==>-5.5109290687386, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 48ms/step
# Episode==>0, Step==>24, Reward==>-5.7351364134236, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 80ms/step
# Episode==>0, Step==>25, Reward==>-6.0845425201031, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 54ms/step
# Episode==>0, Step==>26, Reward==>-6.4125833189351, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 49ms/step
# Episode==>0, Step==>27, Reward==>-6.707853482406501, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 64ms/step
# Episode==>0, Step==>28, Reward==>-7.0311996721806995, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 44ms/step
# Episode==>0, Step==>29, Reward==>-7.353885597583001, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 66ms/step
# Episode==>0, Step==>30, Reward==>-7.6509800649205, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 50ms/step
# Episode==>0, Step==>31, Reward==>-7.9720319039342, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 57ms/step
# Episode==>0, Step==>32, Reward==>-8.2896711068377, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 45ms/step
# Episode==>0, Step==>33, Reward==>-8.5564987230543, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 63ms/step
# Episode==>0, Step==>34, Reward==>-8.935843284131499, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 49ms/step
# Episode==>0, Step==>35, Reward==>-100, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 47ms/step
# Episode==>0, Step==>36, Reward==>3.6648732468178, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 58ms/step
# Episode==>0, Step==>37, Reward==>3.8238801307526997, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 37ms/step
# Episode==>0, Step==>38, Reward==>3.8926748869143, Action ==> 1, State == 0
# 1/1 [==============================] - 0s 50ms/step
# Episode==>0, Step==>39, Reward==>4.0108987799188, Action ==> 1, State == 0
# INFO:tensorflow:Assets written to: dqn/perseguidor.tf/assets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 import matplotlib.pyplot as plt
#       4 train = Train(True)
# ----> 5 train.start()
#
# File ~/posgraduacao/tcc/projeto/agent/train.py:27, in Train.start(self, episodes, steps)
#      25 gamestate = self.env._get_info()['info']['gamestate']
#      26 if gamestate==1:
# ---> 27     action = self.agent.act(state)
#      28     self.agent.history['action_history'].append(action)
#      30     prev_state = state
#
# File ~/posgraduacao/tcc/projeto/agent/main.py:68, in DQN.act(self, state)
#      66 if np.random.rand() <= self.epsilon:
#      67     return random.randrange(self.action_space)
# ---> 68 act_values = self.model.predict(state)
#      69 return np.argmax(act_values[0])
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/keras/engine/training.py:2317, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2308     except ValueError:
#    2309         warnings.warn(
#    2310             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2311             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2314             stacklevel=2,
#    2315         )
# -> 2317 data_handler = data_adapter.get_data_handler(
#    2318     x=x,
#    2319     batch_size=batch_size,
#    2320     steps_per_epoch=steps,
#    2321     initial_epoch=0,
#    2322     epochs=1,
#    2323     max_queue_size=max_queue_size,
#    2324     workers=workers,
#    2325     use_multiprocessing=use_multiprocessing,
#    2326     model=self,
#    2327     steps_per_execution=self._steps_per_execution,
#    2328 )
#    2330 # Container that configures and calls `tf.keras.Callback`s.
#    2331 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/keras/engine/data_adapter.py:1579, in get_data_handler(*args, **kwargs)
#    1577 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579 return DataHandler(*args, **kwargs)
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/keras/engine/data_adapter.py:1259, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1256     self._steps_per_execution = steps_per_execution
#    1258 adapter_cls = select_data_adapter(x, y)
# -> 1259 self._adapter = adapter_cls(
#    1260     x,
#    1261     y,
#    1262     batch_size=batch_size,
#    1263     steps=steps_per_epoch,
#    1264     epochs=epochs - initial_epoch,
#    1265     sample_weights=sample_weight,
#    1266     shuffle=shuffle,
#    1267     max_queue_size=max_queue_size,
#    1268     workers=workers,
#    1269     use_multiprocessing=use_multiprocessing,
#    1270     distribution_strategy=tf.distribute.get_strategy(),
#    1271     model=model,
#    1272 )
#    1274 strategy = tf.distribute.get_strategy()
#    1276 self._current_step = 0
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/keras/engine/data_adapter.py:347, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     343     return flat_dataset
#     345 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 347 dataset = self.slice_inputs(indices_dataset, inputs)
#     349 if shuffle == "batch":
#     351     def shuffle_batch(*batch):
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/keras/engine/data_adapter.py:388, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     383 def grab_batch(i, data):
#     384     return tf.nest.map_structure(
#     385         lambda d: tf.gather(d, i, axis=0), data
#     386     )
# --> 388 dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     390 # Default optimizations are disabled to avoid the overhead of
#     391 # (unnecessary) input pipeline graph serialization and deserialization
#     392 options = tf.data.Options()
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:2296, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2294   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2295 else:
# -> 2296   return ParallelMapDataset(
#    2297       self,
#    2298       map_func,
#    2299       num_parallel_calls,
#    2300       deterministic,
#    2301       preserve_cardinality=True,
#    2302       name=name)
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:5555, in ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5552 self._num_parallel_calls = ops.convert_to_tensor(
#    5553     num_parallel_calls, dtype=dtypes.int64, name="num_parallel_calls")
#    5554 self._name = name
# -> 5555 variant_tensor = gen_dataset_ops.parallel_map_dataset_v2(
#    5556     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    5557     self._map_func.function.captured_inputs,
#    5558     f=self._map_func.function,
#    5559     num_parallel_calls=self._num_parallel_calls,
#    5560     deterministic=self._deterministic,
#    5561     use_inter_op_parallelism=self._use_inter_op_parallelism,
#    5562     preserve_cardinality=self._preserve_cardinality,
#    5563     **self._common_args)
#    5564 super(ParallelMapDataset, self).__init__(input_dataset, variant_tensor)
#
# File ~/anaconda3/envs/Perseguidor/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py:6024, in parallel_map_dataset_v2(input_dataset, other_arguments, num_parallel_calls, f, output_types, output_shapes, use_inter_op_parallelism, deterministic, preserve_cardinality, metadata, name)
#    6022 if tld.is_eager:
#    6023   try:
# -> 6024     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6025       _ctx, "ParallelMapDatasetV2", name, input_dataset, other_arguments,
#    6026       num_parallel_calls, "f", f, "output_types", output_types,
#    6027       "output_shapes", output_shapes, "use_inter_op_parallelism",
#    6028       use_inter_op_parallelism, "deterministic", deterministic,
#    6029       "preserve_cardinality", preserve_cardinality, "metadata", metadata)
#    6030     return _result
#    6031   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
avg = train.agent.history['avg_reward']
loss = train.agent.history['loss_history']
plt.plot(avg)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()
plt.plot(loss)
